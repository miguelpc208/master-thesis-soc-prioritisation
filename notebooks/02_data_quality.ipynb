# %% [markdown]
# # Synthetic data quality
# Checks deterministic fixture identity before external-data profiling is implemented.

# %%
from thesis_pipeline.config import load_scenario
from thesis_pipeline.synthetic_org import generate_dataset

scenario = load_scenario("configs/scenarios/smoke.yaml")
dataset = generate_dataset(scenario)
{"findings": len(dataset.findings), "fingerprint": dataset.fingerprint}

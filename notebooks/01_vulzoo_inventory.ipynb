# %% [markdown]
# # VulZoo inventory
# Requires an approved `THESIS_DATA_ROOT` and an existing shallow clone. It never downloads data.

# %%
from thesis_pipeline.ingestion import inventory_vulzoo

inventory_vulzoo("configs/data_sources.yaml")

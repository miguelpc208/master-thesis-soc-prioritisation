# %% [markdown]
# # Experiment-result inspection
# Load only validated run directories. Smoke metrics are not dissertation findings.

# %%
from pathlib import Path

runs = sorted(Path("outputs").glob("*/manifest.json"))
[str(path.parent) for path in runs[-5:]]
